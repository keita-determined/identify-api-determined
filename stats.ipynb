# %% [markdown]
# # Identify All API Calls

# %%
import pandas as pd
import json
import os
from collections import defaultdict
import re
import random

# %%
"""
there are 3 API patters
http://localhost:3000/api/v1/master
http://latest-main.determined.ai:8080/api/v1/master
http://latest-ee-gke-main.determined.ai/api/v1/master
"""
API_PATTERN = r"^http://(latest-(main|ee-gke-main)\.determined\.ai|localhost)(:8080|:3000)?/api"

def get_file(trace_list) -> list[str]:
    api_set = set()
    for obj in trace_list:
        try:
            data_url = str(obj["args"]["url"])
            if re.match(API_PATTERN, data_url, re.IGNORECASE):
                api_set.add(re.sub(API_PATTERN, "", data_url, re.IGNORECASE))
                continue
        except:
            pass
        try:
            data_url = str(obj["args"]["data"]["url"])
            if re.match(API_PATTERN, data_url, re.IGNORECASE):
                api_set.add(re.sub(API_PATTERN, "", data_url, re.IGNORECASE))
        except:
            pass
    return sorted(list(api_set))

# %%
files = sorted(os.listdir("data"))
api_dict: dict[str, list[str]] = defaultdict(list)
for file in files:
    if not file.lower().endswith("json"):
        continue
    try:
        json_open = open(f"./data/{file}", "r")
        json_load = json.load(json_open)
        trace_list = json_load["traceEvents"]
        api_dict["url"] += [file.split(".")[0].replace(":", "/")]
        api_dict["api"] += [get_file(trace_list)]
        api_dict["root_url"] += [file.split(":")[0]]
    except:
        print(file)
        break

# %%
def generate_colors() -> dict[str, str]:
    color_dict = {}
    for i, file in enumerate(files):
        if not file.lower().endswith("json"):
            continue
        random.seed(i * 10)
        color = "%06x" % random.randint(0, 0xFFFFFF)
        color_dict[file.split(".")[0].replace(":", "/")] = f"#{color}97"
    return color_dict


generate_colors()
# Out:
# {'admin/group-management': '#10aefd97',
#  'admin/user-management': '#4d6ac797',
#  'clusters': '#94118e97',
#  'clusters/historical-usage': '#eace7f97',
#  'clusters/logs': '#febd1c97',
#  'dashboard': '#9d98d897',
#  'experiments/{experiment_id}/checkpoints': '#3ca35297',
#  'experiments/{experiment_id}/code': '#8b00e297',
#  'experiments/{experiment_id}/hyperparameters': '#68477e97',
#  'experiments/{experiment_id}/logs': '#4a952997',
#  'experiments/{experiment_id}/metrics': '#c6ac7c97',
#  'experiments/{experiment_id}/notes': '#7eeb4097',
#  'experiments/{experiment_id}/overview': '#d9d67597',
#  'experiments/{experiment_id}/profiler': '#30a57897',
#  'experiments/{experiment_id}/trials': '#a7197797',
#  'experiments/{experiment_id}/trials/{trial_id}/hyperparameters': '#3ebd2b97',
#  'experiments/{experiment_id}/trials/{trial_id}/metrics': '#b0a24697',
#  'experiments/{experiment_id}/trials/{trial_id}/profiler': '#49d9cc97',
#  'experiments/{experiment_id}/trials/{trials_id}/overview': '#26304d97',
#  'experiments/{experiment_id}/visualization/hp-heat-map': '#175a1a97',
#  'experiments/{experiment_id}/visualization/hp-parallel-coordinates': '#c4f7ff97',
#  'experiments/{experiment_id}/visualization/hp-scatter-plots': '#774c9497',
#  'experiments/{experiment_id}/visualization/learning-curve': '#52dafd97',
#  'experiments/{experimentid}/trials/{trial_id}/logs': '#1e08b697',
#  'interactive/{id}/jupyter-lab/{id}/{pool}/{id}': '#c66dc797',
#  'jupyter-lab/{id}': '#6bdd1397',
#  'models': '#5bd9d497',
#  'models/{model_id}': '#9e81f897',
#  'models/{model_id}/versions/{version_id}/model': '#ad37df97',
#  'models/{model_id}/versions/{version_id}/notes': '#b67f3a97',
#  'projects/{project_id}/experiments': '#22863f97',
#  'projects/{project_id}/notes': '#e41c7e97',
#  'resourcepool/{pool}/active': '#24850f97',
#  'resourcepool/{pool}/bindings': '#cccc5c97',
#  'resourcepool/{pool}/configuration': '#b9cf8597',
#  'resourcepool/{pool}/queued': '#7611df97',
#  'resourcepool/{pool}/stats': '#3f9f4197',
#  'tasks': '#43eeb297',
#  'webhooks': '#2d63e397',
#  'workspaces': '#9d891697',
#  'workspaces/{workspace_id}/members': '#4b4e9a97',
#  'workspaces/{workspace_id}/models': '#0d7ce197',
#  'workspaces/{workspace_id}/pools': '#8b3cfc97',
#  'workspaces/{workspace_id}/projects': '#3f9ec097',
#  'workspaces/{workspace_id}/tasks': '#31539f97'}

# %%
pd.set_option("display.max_colwidth", 5000)
df = pd.DataFrame.from_dict(api_dict)
df_collapse = df.explode("api")

# %%
df
# Out:
#                                                                   url  \
# 0                                              admin/group-management
# 1                                               admin/user-management
# 2                                                            clusters
# 3                                           clusters/historical-usage
# 4                                                       clusters/logs
# 5                                                           dashboard
# 6                             experiments/{experiment_id}/checkpoints
# 7                                    experiments/{experiment_id}/code
# 8                         experiments/{experiment_id}/hyperparameters
# 9                                    experiments/{experiment_id}/logs
# 10                                experiments/{experiment_id}/metrics
# 11                                  experiments/{experiment_id}/notes
# 12                               experiments/{experiment_id}/overview
# 13                               experiments/{experiment_id}/profiler
# 14                                 experiments/{experiment_id}/trials
# 15      experiments/{experiment_id}/trials/{trial_id}/hyperparameters
# 16              experiments/{experiment_id}/trials/{trial_id}/metrics
# 17             experiments/{experiment_id}/trials/{trial_id}/profiler
# 18            experiments/{experiment_id}/trials/{trials_id}/overview
# 19              experiments/{experiment_id}/visualization/hp-heat-map
# 20  experiments/{experiment_id}/visualization/hp-parallel-coordinates
# 21         experiments/{experiment_id}/visualization/hp-scatter-plots
# 22           experiments/{experiment_id}/visualization/learning-curve
# 23                  experiments/{experimentid}/trials/{trial_id}/logs
# 24                      interactive/{id}/jupyter-lab/{id}/{pool}/{id}
# 25                                                   jupyter-lab/{id}
# 26                                                             models
# 27                                                  models/{model_id}
# 28                      models/{model_id}/versions/{version_id}/model
# 29                      models/{model_id}/versions/{version_id}/notes
# 30                                  projects/{project_id}/experiments
# 31                                        projects/{project_id}/notes
# 32                                         resourcepool/{pool}/active
# 33                                       resourcepool/{pool}/bindings
# 34                                  resourcepool/{pool}/configuration
# 35                                         resourcepool/{pool}/queued
# 36                                          resourcepool/{pool}/stats
# 37                                                              tasks
# 38                                                           webhooks
# 39                                                         workspaces
# 40                                  workspaces/{workspace_id}/members
# 41                                   workspaces/{workspace_id}/models
# 42                                    workspaces/{workspace_id}/pools
# 43                                 workspaces/{workspace_id}/projects
# 44                                    workspaces/{workspace_id}/tasks
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  api  \
# 0   [/v1/agents, /v1/auth/user, /v1/groups/178, /v1/groups/180, /v1/groups/183, /v1/groups/185, /v1/groups/191, /v1/groups/206, /v1/groups/207, /v1/groups/209, /v1/groups/220, /v1/groups/3, /v1/groups/4, /v1/groups/5, /v1/groups/71, /v1/groups/77, /v1/groups/80, /v1/groups/86, /v1/groups/92, /v1/groups/search, /v1/master, /v1/permissions/summary, /v1/resource-pools, /v1/roles/search, /v1/roles/search/by-group/178, /v1/roles/search/by-group/180, /v1/roles/search/by-group/183, /v1/roles/search/by-group/185, /v1/roles/search/by-group/191, /v1/roles/search/by-group/206, /v1/roles/search/by-group/207, /v1/roles/search/by-group/209, /v1/roles/search/by-group/220, /v1/roles/search/by-group/3, /v1/roles/search/by-group/4, /v1/roles/search/by-group/5, /v1/roles/search/by-group/71, /v1/roles/search/by-group/77, /v1/roles/search/by-group/80, /v1/roles/search/by-group/86, /v1/roles/search/by-group/92, /v1/users, /v1/users/setting, /v1/workspaces]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [/v1/agents, /v1/auth/user, /v1/groups/search, /v1/master, /v1/permissions/summary, /v1/resource-pools, /v1/roles/search, /v1/roles/search/by-user/1, /v1/roles/search/by-user/10, /v1/roles/search/by-user/11, /v1/roles/search/by-user/3, /v1/roles/search/by-user/4, /v1/roles/search/by-user/5, /v1/roles/search/by-user/6, /v1/roles/search/by-user/7, /v1/roles/search/by-user/8, /v1/roles/search/by-user/9, /v1/users, /v1/users/setting, /v1/workspaces]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [/v1/agents, /v1/auth/user, /v1/experiments?limit=-2&states=STATE_ACTIVE&states=STATE_STOPPING_CANCELED&states=STATE_STOPPING_COMPLETED&states=STATE_STOPPING_ERROR&projectId=0&showTrialData=true, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/resource-pools/aux-pool/workspace-bindings, /v1/resource-pools/compute-pool/workspace-bindings, /v1/tasks/count, /v1/users, /v1/users/setting, /v1/workspaces]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [/v1/agents, /v1/auth/user, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/resources/allocation/aggregated?startDate=2023-08-03&endDate=2023-08-22&period=RESOURCE_ALLOCATION_AGGREGATION_PERIOD_DAILY, /v1/resources/allocation/aggregated?startDate=2023-08-08&endDate=2023-08-22&period=RESOURCE_ALLOCATION_AGGREGATION_PERIOD_DAILY, /v1/users, /v1/users/setting, /v1/workspaces]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [/v1/agents, /v1/auth/user, /v1/master, /v1/master/logs?offset=-1&limit=0&follow=true, /v1/master/logs?offset=-100&limit=100&follow=false, /v1/master/telemetry, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 5                                                                                                                                                                                                                                                                                                                                                      [/v1/agents, /v1/auth/user, /v1/commands?sortBy=SORT_BY_START_TIME&orderBy=ORDER_BY_DESC&limit=25&userIds=1, /v1/experiments?sortBy=SORT_BY_START_TIME&orderBy=ORDER_BY_DESC&limit=25&userIds=1&projectId=0&showTrialData=true, /v1/master, /v1/master/telemetry, /v1/notebooks?sortBy=SORT_BY_START_TIME&orderBy=ORDER_BY_DESC&limit=25&userIds=1, /v1/resource-pools, /v1/shells?sortBy=SORT_BY_START_TIME&orderBy=ORDER_BY_DESC&limit=25&userIds=1, /v1/tensorboards?sortBy=SORT_BY_START_TIME&orderBy=ORDER_BY_DESC&limit=25&userIds=1, /v1/user/projects/activity?limit=5, /v1/users, /v1/users/setting, /v1/workspaces]
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [/v1/agents, /v1/auth/user, /v1/experiments/3829, /v1/experiments/3829/checkpoints?sortBy=SORT_BY_UUID&orderBy=ORDER_BY_DESC&offset=0&limit=10, /v1/experiments/3829/trials?limit=2, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/trials/34667, /v1/users, /v1/users/setting, /v1/workspaces]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [/v1/agents, /v1/auth/user, /v1/experiments/3829, /v1/experiments/3829/file, /v1/experiments/3829/file_tree, /v1/experiments/3829/trials?limit=2, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/trials/34667, /v1/users, /v1/users/setting, /v1/workspaces]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [/v1/agents, /v1/auth/user, /v1/experiments/3829, /v1/experiments/3829/trials?limit=2, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/trials/34667, /v1/users, /v1/users/setting, /v1/workspaces]
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [/v1/agents, /v1/auth/user, /v1/experiments/3829, /v1/experiments/3829/trials?limit=2, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/trials/34667, /v1/trials/34667/logs/fields?follow=true, /v1/trials/34667/logs?limit=0&follow=true&timestampAfter=2023-08-23T21%3A01%3A33.313Z&orderBy=ORDER_BY_ASC, /v1/trials/34667/logs?limit=100&follow=false&orderBy=ORDER_BY_DESC, /v1/users, /v1/users/setting, /v1/workspaces]
# 10                                                                                                                                                                                                                                                                          [/v1/agents, /v1/auth/user, /v1/experiments/3829, /v1/experiments/3829/trials?limit=2, /v1/experiments/metrics-stream/metric-names?ids=3829, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/trials/34667, /v1/trials/time-series?maxDatapoints=1500&startBatches=0&metricType=METRIC_TYPE_UNSPECIFIED, /v1/trials/time-series?trialIds=34667&maxDatapoints=1500&startBatches=0&metricType=METRIC_TYPE_UNSPECIFIED, /v1/trials/time-series?trialIds=34667&maxDatapoints=1500&startBatches=0&metricType=METRIC_TYPE_UNSPECIFIED&metricIds=training.loss&metricIds=training.lr&metricIds=validation.accuracy&metricIds=validation.validation_loss, /v1/users, /v1/users/setting, /v1/workspaces]
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [/v1/agents, /v1/auth/user, /v1/experiments/3829, /v1/experiments/3829/trials?limit=2, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/trials/34667, /v1/users, /v1/users/setting, /v1/workspaces]
# 12                                                                                                                                                                                                                                                                                                                   [/v1/agents, /v1/auth/user, /v1/experiments/3829, /v1/experiments/3829/trials?limit=2, /v1/experiments/metrics-stream/metric-names?ids=3829, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/trials/34667, /v1/trials/34667/workloads?orderBy=ORDER_BY_DESC&offset=0&limit=10&sortKey=batches&filter=FILTER_OPTION_CHECKPOINT_OR_VALIDATION&removeDeletedCheckpoints=true, /v1/trials/time-series?trialIds=34667&maxDatapoints=1500&startBatches=0&metricType=METRIC_TYPE_UNSPECIFIED&metricIds=training.loss&metricIds=training.lr&metricIds=validation.accuracy&metricIds=validation.validation_loss, /v1/users, /v1/users/setting, /v1/workspaces]
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [/v1/agents, /v1/auth/user, /v1/experiments/3829, /v1/experiments/3829/trials?limit=2, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/trials/34667, /v1/users, /v1/users/setting, /v1/workspaces]
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [/v1/agents, /v1/auth/user, /v1/experiments/3235, /v1/experiments/3235/trials?sortBy=SORT_BY_ID&orderBy=ORDER_BY_DESC&offset=0&limit=10, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 15                                                                                                                                                                                                                                                                                                                                                             [/v1/agents, /v1/auth/user, /v1/experiments/3235, /v1/experiments/3235/metrics-stream/batches?metricName=validation_error&metricType=METRIC_TYPE_VALIDATION, /v1/experiments/3235/metrics-stream/trials-snapshot?metricName=validation_error&metricType=METRIC_TYPE_VALIDATION&batchesProcessed=6252&batchesMargin=10, /v1/experiments/metrics-stream/metric-names?ids=3235, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/trials/11994, /v1/trials/11994/workloads?limit=1&sortKey=batches&filter=FILTER_OPTION_UNSPECIFIED&removeDeletedCheckpoints=true, /v1/users, /v1/users/setting, /v1/workspaces]
# 16                                                                                                                                                                                                                                  [/v1/agents, /v1/auth/user, /v1/experiments/3235, /v1/experiments/metrics-stream/metric-names?ids=3235, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/trials/11994, /v1/trials/11994/workloads?limit=1&sortKey=batches&filter=FILTER_OPTION_UNSPECIFIED&removeDeletedCheckpoints=true, /v1/trials/time-series?trialIds=11994&maxDatapoints=1500&startBatches=0&metricType=METRIC_TYPE_UNSPECIFIED, /v1/trials/time-series?trialIds=11994&maxDatapoints=1500&startBatches=0&metricType=METRIC_TYPE_UNSPECIFIED&metricIds=training.loss&metricIds=training.train_accuracy&metricIds=training.train_error&metricIds=validation.validation_accuracy&metricIds=validation.validation_error, /v1/users, /v1/users/setting, /v1/workspaces]
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [/v1/agents, /v1/auth/user, /v1/experiments/3235, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/trials/11994, /v1/trials/11994/workloads?limit=1&sortKey=batches&filter=FILTER_OPTION_UNSPECIFIED&removeDeletedCheckpoints=true, /v1/users, /v1/users/setting, /v1/workspaces]
# 18                                                                  [/v1/agents, /v1/auth/user, /v1/experiments/3235, /v1/experiments/metrics-stream/metric-names?ids=3235, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/trials/11994, /v1/trials/11994/workloads?limit=1&sortKey=batches&filter=FILTER_OPTION_UNSPECIFIED&removeDeletedCheckpoints=true, /v1/trials/11994/workloads?orderBy=ORDER_BY_DESC&offset=0&limit=10&sortKey=batches&filter=FILTER_OPTION_CHECKPOINT_OR_VALIDATION&removeDeletedCheckpoints=true, /v1/trials/time-series?trialIds=11994&maxDatapoints=1500&startBatches=0&metricType=METRIC_TYPE_UNSPECIFIED, /v1/trials/time-series?trialIds=11994&maxDatapoints=1500&startBatches=0&metricType=METRIC_TYPE_UNSPECIFIED&metricIds=training.loss&metricIds=training.train_accuracy&metricIds=training.train_error&metricIds=validation.validation_accuracy&metricIds=validation.validation_error, /v1/users, /v1/users/setting, /v1/workspaces]
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [/v1/agents, /v1/auth/user, /v1/experiments/3235, /v1/experiments/3235/metrics-stream/batches?metricName=validation_error&metricType=METRIC_TYPE_VALIDATION, /v1/experiments/3235/metrics-stream/trials-snapshot?metricName=validation_error&metricType=METRIC_TYPE_VALIDATION&batchesProcessed=782&batchesMargin=10, /v1/experiments/metrics-stream/metric-names?ids=3235, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [/v1/agents, /v1/auth/user, /v1/experiments/3235, /v1/experiments/3235/metrics-stream/batches?metricName=validation_error&metricType=METRIC_TYPE_VALIDATION, /v1/experiments/3235/metrics-stream/trials-snapshot?metricName=validation_error&metricType=METRIC_TYPE_VALIDATION&batchesProcessed=782&batchesMargin=10, /v1/experiments/metrics-stream/metric-names?ids=3235, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [/v1/agents, /v1/auth/user, /v1/experiments/3235, /v1/experiments/3235/metrics-stream/batches?metricName=validation_error&metricType=METRIC_TYPE_VALIDATION, /v1/experiments/3235/metrics-stream/trials-snapshot?metricName=validation_error&metricType=METRIC_TYPE_VALIDATION&batchesProcessed=782&batchesMargin=10, /v1/experiments/metrics-stream/metric-names?ids=3235, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [/v1/agents, /v1/auth/user, /v1/experiments/3235, /v1/experiments/3235/metrics-stream/batches?metricName=validation_error&metricType=METRIC_TYPE_VALIDATION, /v1/experiments/3235/metrics-stream/trials-sample?metricName=validation_error&metricType=METRIC_TYPE_VALIDATION&maxTrials=100&maxDatapoints=5000, /v1/experiments/metrics-stream/metric-names?ids=3235, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                              [/v1/agents, /v1/auth/user, /v1/experiments/3235, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/trials/11994, /v1/trials/11994/logs/fields?follow=true, /v1/trials/11994/logs?limit=0&follow=true&timestampAfter=2023-08-23T22%3A04%3A23.997Z&orderBy=ORDER_BY_ASC, /v1/trials/11994/logs?limit=100&follow=false&orderBy=ORDER_BY_DESC, /v1/trials/11994/workloads?limit=1&sortKey=batches&filter=FILTER_OPTION_UNSPECIFIED&removeDeletedCheckpoints=true, /v1/users, /v1/users/setting, /v1/workspaces]
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [/v1/agents, /v1/auth/user, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/tasks/997761ad-d8f5-45e9-8a25-6e2a418826e6, /v1/users, /v1/users/setting, /v1/workspaces]
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [/v1/agents, /v1/auth/user, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/tasks/997761ad-d8f5-45e9-8a25-6e2a418826e6/logs/fields?follow=true, /v1/tasks/997761ad-d8f5-45e9-8a25-6e2a418826e6/logs?limit=0&follow=true&timestampAfter=2023-08-23T21%3A11%3A56.553Z&orderBy=ORDER_BY_ASC, /v1/tasks/997761ad-d8f5-45e9-8a25-6e2a418826e6/logs?limit=100&follow=false&orderBy=ORDER_BY_DESC, /v1/users, /v1/users/setting, /v1/workspaces]
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [/v1/agents, /v1/auth/user, /v1/master, /v1/master/telemetry, /v1/model/labels, /v1/models?sortBy=SORT_BY_CREATION_TIME&orderBy=ORDER_BY_DESC&offset=0&limit=10&archived=false, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [/v1/agents, /v1/auth/user, /v1/master, /v1/master/telemetry, /v1/models/760/versions?sortBy=SORT_BY_VERSION&orderBy=ORDER_BY_DESC&offset=0&limit=10, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [/v1/agents, /v1/auth/user, /v1/master, /v1/master/telemetry, /v1/models/760/versions/15, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [/v1/agents, /v1/auth/user, /v1/master, /v1/master/telemetry, /v1/models/760/versions/15, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [/v1/agents, /v1/auth/user, /v1/experiments-search?projectId=1&offset=0&limit=200&sort=id%3Ddesc&filter=%7B%22filterGroup%22%3A%7B%22children%22%3A%5B%5D%2C%22conjunction%22%3A%22and%22%2C%22kind%22%3A%22group%22%7D%2C%22showArchived%22%3Afalse%7D, /v1/master, /v1/master/telemetry, /v1/projects/1, /v1/projects/1/columns, /v1/projects/1/experiments/metric-ranges, /v1/resource-pools, /v1/users, /v1/users/activity, /v1/users/setting, /v1/workspaces]
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [/v1/agents, /v1/auth/user, /v1/master, /v1/master/telemetry, /v1/projects/113, /v1/resource-pools, /v1/users, /v1/users/activity, /v1/users/setting, /v1/workspaces]
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [/v1/agents, /v1/auth/user, /v1/job-queues-v2?offset=0&limit=1&resourcePool=compute-pool, /v1/job-queues-v2?offset=0&limit=10&resourcePool=compute-pool&orderBy=ORDER_BY_ASC&states=STATE_SCHEDULED, /v1/job-queues/stats, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [/v1/agents, /v1/auth/user, /v1/job-queues/stats, /v1/master, /v1/permissions/summary, /v1/resource-pools, /v1/resource-pools/pool_1/workspace-bindings, /v1/users, /v1/users/setting, /v1/workspaces]
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [/v1/agents, /v1/auth/user, /v1/job-queues/stats, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [/v1/agents, /v1/auth/user, /v1/job-queues-v2?offset=0&limit=1&resourcePool=compute-pool, /v1/job-queues-v2?offset=0&limit=10&resourcePool=compute-pool&orderBy=ORDER_BY_ASC&states=STATE_QUEUED, /v1/job-queues/stats, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 36                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [/v1/agents, /v1/auth/user, /v1/job-queues/stats, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces]
# 37                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [/v1/agents, /v1/auth/user, /v1/commands?limit=1000, /v1/master, /v1/master/telemetry, /v1/notebooks?limit=1000, /v1/resource-pools, /v1/shells?limit=1000, /v1/tensorboards?limit=1000, /v1/users, /v1/users/setting, /v1/workspaces]
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [/v1/agents, /v1/auth/user, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/webhooks, /v1/workspaces]
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [/v1/agents, /v1/auth/user, /v1/master, /v1/master/telemetry, /v1/resource-pools, /v1/users, /v1/users/setting, /v1/workspaces, /v1/workspaces?sortBy=SORT_BY_NAME&orderBy=ORDER_BY_ASC&offset=0&limit=0&archived=false]
# 40                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [/v1/agents, /v1/auth/user, /v1/groups/search, /v1/master, /v1/permissions/summary, /v1/resource-pools, /v1/roles/search/by-assignability, /v1/roles/workspace/2, /v1/roles/workspace/2?name=testtt, /v1/users, /v1/users/setting, /v1/workspaces]
# 41                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [/v1/agents, /v1/auth/user, /v1/groups/search, /v1/master, /v1/model/labels?workspaceId=2, /v1/models?sortBy=SORT_BY_CREATION_TIME&orderBy=ORDER_BY_DESC&offset=0&limit=10&archived=false&workspaceIds=2, /v1/permissions/summary, /v1/resource-pools, /v1/roles/search/by-assignability, /v1/roles/workspace/2, /v1/users, /v1/users/setting, /v1/workspaces]
# 42                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [/v1/agents, /v1/auth/user, /v1/groups/search, /v1/master, /v1/permissions/summary, /v1/resource-pools, /v1/resource-pools/default/workspace-bindings, /v1/resource-pools?unbound=true, /v1/roles/search/by-assignability, /v1/roles/workspace/2, /v1/users, /v1/users/setting, /v1/workspaces, /v1/workspaces/2/available-resource-pools]
# 43                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [/v1/agents, /v1/auth/user, /v1/groups/search, /v1/master, /v1/permissions/summary, /v1/resource-pools, /v1/roles/search/by-assignability, /v1/roles/workspace/2, /v1/users, /v1/users/setting, /v1/workspaces, /v1/workspaces/2/projects?sortBy=SORT_BY_LAST_EXPERIMENT_START_TIME&orderBy=ORDER_BY_DESC&offset=0&limit=0&archived=false]
# 44                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [/v1/agents, /v1/auth/user, /v1/commands?limit=1000&workspaceId=2, /v1/groups/search, /v1/master, /v1/notebooks?limit=1000&workspaceId=2, /v1/permissions/summary, /v1/resource-pools, /v1/roles/search/by-assignability, /v1/roles/workspace/2, /v1/shells?limit=1000&workspaceId=2, /v1/tensorboards?limit=1000&workspaceId=2, /v1/users, /v1/users/setting, /v1/workspaces]
#
#            root_url
# 0             admin
# 1             admin
# 2     clusters.json
# 3          clusters
# 4          clusters
# 5    dashboard.json
# 6       experiments
# 7       experiments
# 8       experiments
# 9       experiments
# 10      experiments
# 11      experiments
# 12      experiments
# 13      experiments
# 14      experiments
# 15      experiments
# 16      experiments
# 17      experiments
# 18      experiments
# 19      experiments
# 20      experiments
# 21      experiments
# 22      experiments
# 23      experiments
# 24      interactive
# 25      jupyter-lab
# 26      models.json
# 27           models
# 28           models
# 29           models
# 30         projects
# 31         projects
# 32     resourcepool
# 33     resourcepool
# 34     resourcepool
# 35     resourcepool
# 36     resourcepool
# 37       tasks.json
# 38    webhooks.json
# 39  workspaces.json
# 40       workspaces
# 41       workspaces
# 42       workspaces
# 43       workspaces
# 44       workspaces

# %%
df_collapse = df_collapse.reset_index(drop=True)
df_collapse = df_collapse.drop(columns=['root_url'])

# %%
df_collapse
# Out:
#                                  url  \
# 0             admin/group-management
# 1             admin/group-management
# 2             admin/group-management
# 3             admin/group-management
# 4             admin/group-management
# ..                               ...
# 558  workspaces/{workspace_id}/tasks
# 559  workspaces/{workspace_id}/tasks
# 560  workspaces/{workspace_id}/tasks
# 561  workspaces/{workspace_id}/tasks
# 562  workspaces/{workspace_id}/tasks
#
#                                            api
# 0                                   /v1/agents
# 1                                /v1/auth/user
# 2                               /v1/groups/178
# 3                               /v1/groups/180
# 4                               /v1/groups/183
# ..                                         ...
# 558        /v1/shells?limit=1000&workspaceId=2
# 559  /v1/tensorboards?limit=1000&workspaceId=2
# 560                                  /v1/users
# 561                          /v1/users/setting
# 562                             /v1/workspaces
#
# [563 rows x 2 columns]

# %% [markdown]
# Output HTML with some styling

# %%
HTML_OUTPUT = "./stats.html"
color_dict = generate_colors()

with open(HTML_OUTPUT, mode="w") as f:
    f.write(
        df_collapse.style.applymap(
            lambda x: f'background-color: {color_dict.get(x, "")}', subset=["url"]
        )
        .set_table_styles(
            [
                {
                    "selector": "tbody tr:nth-child(even)",
                    "props": [("background-color", "#ededed")],
                },
                {
                    "selector": "tr > th, tr > td",
                    "props": [("border", "1px solid gray"), ("padding", "4px 8px")],
                },
                {
                    "selector": "",
                    "props": [("border-collapse", "collapse")],
                }
            ]
        )
        .to_html(columns=["url", "api"], justify="left")
    )
